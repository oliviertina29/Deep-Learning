# %%
# importing libraries
import numpy as np
import tensorflow as tf
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.layers import Convolution2D, MaxPooling2D
from keras.layers import Flatten
from keras.utils import np_utils
from keras.datasets import cifar10

np.random.seed(1)
tf.random.set_seed(1)

# %% [markdown]
# ## Mnist

# %%
(X_train, Y_train), (X_test, Y_test) = mnist.load_data()
X_train = X_train.reshape(60000, 28, 28, 1)
X_test = X_test.reshape(10000, 28, 28, 1)

Y_train = np_utils.to_categorical(Y_train, 10)
Y_test = np_utils.to_categorical(Y_test, 10)

model = Sequential([
Convolution2D(filters=32,
kernel_size=(3, 3),
input_shape=(28, 28, 1)), # first conv layer
Activation('relu'),
Convolution2D(filters=32,
kernel_size=(3, 3)), # second conv layer
Activation('relu'),
MaxPooling2D(pool_size=(2, 2)), # max pooling layer
Flatten(), # flatten the output tensor
Dense(64), # fully-connected hidden layer
Activation('relu'),
Dense(10), # output layer
Activation('softmax')])
print(model.summary())

model.compile(loss='categorical_crossentropy',
metrics=['accuracy'], optimizer='adadelta')
model.fit(X_train, Y_train, batch_size=100, epochs=5,
validation_split=0.1, verbose=1)

score = model.evaluate(X_test, Y_test, verbose=1)
print('Test accuracy:', score[1])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 32)        320
#
#  activation (Activation)     (None, 26, 26, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 24, 24, 32)        9248
#
#  activation_1 (Activation)   (None, 24, 24, 32)        0
#
#  max_pooling2d (MaxPooling2D  (None, 12, 12, 32)       0
#  )
#
#  flatten (Flatten)           (None, 4608)              0
#
#  dense (Dense)               (None, 64)                294976
#
#  activation_2 (Activation)   (None, 64)                0
#
#  dense_1 (Dense)             (None, 10)                650
#
#  activation_3 (Activation)   (None, 10)                0
#
# =================================================================
# Total params: 305,194
# Trainable params: 305,194
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/5
# 540/540 [==============================] - 101s 185ms/step - loss: 11.7916 - accuracy: 0.2200 - val_loss: 6.7928 - val_accuracy: 0.3445
# Epoch 2/5
# 540/540 [==============================] - 103s 190ms/step - loss: 5.3291 - accuracy: 0.4115 - val_loss: 3.8183 - val_accuracy: 0.5078
# Epoch 3/5
# 540/540 [==============================] - 97s 180ms/step - loss: 3.2659 - accuracy: 0.5464 - val_loss: 2.4211 - val_accuracy: 0.6195
# Epoch 4/5
# 540/540 [==============================] - 100s 186ms/step - loss: 2.2606 - accuracy: 0.6378 - val_loss: 1.7214 - val_accuracy: 0.7027
# Epoch 5/5
# 540/540 [==============================] - 103s 191ms/step - loss: 1.7353 - accuracy: 0.6971 - val_loss: 1.3501 - val_accuracy: 0.7468
# 313/313 [==============================] - 4s 13ms/step - loss: 1.5576 - accuracy: 0.7268
# Test accuracy: 0.7268000245094299

# %% [markdown]
# ## Cifar10

# %%
(X_train, Y_train), (X_test, Y_test) = cifar10.load_data()

# Reformatage des images
X_train = X_train.reshape(X_train.shape[0], 32, 32, 3)
X_test = X_test.reshape(X_test.shape[0], 32, 32, 3)

classes = 10
Y_train = np_utils.to_categorical(Y_train, classes)
Y_test = np_utils.to_categorical(Y_test, classes)

model = Sequential([
    Convolution2D(32, (5, 5), padding='same', input_shape=(32, 32, 3)),
    Activation('relu'),
    MaxPooling2D(pool_size=(2, 2)),
    Convolution2D(64, (5, 5)),
    Activation('relu'),
    MaxPooling2D(pool_size=(2, 2)),
    Convolution2D(64, (5, 5)),
    Activation('relu'),
    MaxPooling2D(pool_size=(2, 2)),
    Flatten(),
    Dense(64),
    Activation('relu'),
    Dense(10),
    Activation('softmax')
])

print(model.summary())

model.compile(loss='categorical_crossentropy',
              metrics=['accuracy'], optimizer='adadelta')
model.fit(X_train, Y_train, batch_size=100, epochs=30, validation_split=0.1, verbose=1)

score = model.evaluate(X_test, Y_test, verbose=1)
print('Test accuracy:', score[1])
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_14 (Conv2D)          (None, 32, 32, 32)        2432
#
#  activation_24 (Activation)  (None, 32, 32, 32)        0
#
#  max_pooling2d_13 (MaxPoolin  (None, 16, 16, 32)       0
#  g2D)
#
#  conv2d_15 (Conv2D)          (None, 12, 12, 64)        51264
#
#  activation_25 (Activation)  (None, 12, 12, 64)        0
#
#  max_pooling2d_14 (MaxPoolin  (None, 6, 6, 64)         0
#  g2D)
#
#  conv2d_16 (Conv2D)          (None, 2, 2, 64)          102464
#
#  activation_26 (Activation)  (None, 2, 2, 64)          0
#
#  max_pooling2d_15 (MaxPoolin  (None, 1, 1, 64)         0
#  g2D)
#
#  flatten_5 (Flatten)         (None, 64)                0
#
#  dense_10 (Dense)            (None, 64)                4160
#
#  activation_27 (Activation)  (None, 64)                0
#
#  dense_11 (Dense)            (None, 10)                650
#
#  activation_28 (Activation)  (None, 10)                0
#
# =================================================================
# Total params: 160,970
# Trainable params: 160,970
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/30
#
# Epoch 19/30
# 450/450 [==============================] - 114s 254ms/step - loss: 2.1147 - accuracy: 0.2978 - val_loss: 2.1339 - val_accuracy: 0.2944
# Epoch 20/30
# 450/450 [==============================] - 116s 258ms/step - loss: 2.0919 - accuracy: 0.3019 - val_loss: 2.1140 - val_accuracy: 0.2942
# Epoch 21/30
# 450/450 [==============================] - 115s 256ms/step - loss: 2.0713 - accuracy: 0.3059 - val_loss: 2.0931 - val_accuracy: 0.2938
# Epoch 22/30
# 450/450 [==============================] - 113s 252ms/step - loss: 2.0517 - accuracy: 0.3095 - val_loss: 2.0740 - val_accuracy: 0.3018
# Epoch 23/30
# 450/450 [==============================] - 113s 252ms/step - loss: 2.0326 - accuracy: 0.3133 - val_loss: 2.0577 - val_accuracy: 0.3038
# Epoch 24/30
# 450/450 [==============================] - 116s 259ms/step - loss: 2.0152 - accuracy: 0.3179 - val_loss: 2.0433 - val_accuracy: 0.3046
# Epoch 25/30
# 450/450 [==============================] - 114s 253ms/step - loss: 1.9984 - accuracy: 0.3205 - val_loss: 2.0262 - val_accuracy: 0.3082
# Epoch 26/30
# 450/450 [==============================] - 114s 253ms/step - loss: 1.9829 - accuracy: 0.3244 - val_loss: 2.0138 - val_accuracy: 0.3110
# Epoch 27/30
# 450/450 [==============================] - 113s 250ms/step - loss: 1.9683 - accuracy: 0.3273 - val_loss: 1.9972 - val_accuracy: 0.3170
# Epoch 28/30
# 450/450 [==============================] - 116s 259ms/step - loss: 1.9540 - accuracy: 0.3303 - val_loss: 1.9890 - val_accuracy: 0.3136
# Epoch 29/30
# 450/450 [==============================] - 116s 259ms/step - loss: 1.9406 - accuracy: 0.3325 - val_loss: 1.9741 - val_accuracy: 0.3192
# Epoch 30/30
# 450/450 [==============================] - 114s 253ms/step - loss: 1.9275 - accuracy: 0.3361 - val_loss: 1.9675 - val_accuracy: 0.3176
# 313/313 [==============================] - 7s 21ms/step - loss: 1.9716 - accuracy: 0.3237
# Test accuracy: 0.3237000107765198

# %%
model = Sequential([
    Convolution2D(32, (5, 5), padding='same', input_shape=(32, 32, 3)),
    Activation('relu'),
    MaxPooling2D(pool_size=(2, 2)),
    Convolution2D(64, (5, 5)),
    Activation('relu'),
    MaxPooling2D(pool_size=(2, 2)),
    Convolution2D(64, (5, 5)),
    Activation('relu'),
    MaxPooling2D(pool_size=(2, 2)),
    Flatten(),
    Dense(64),
    Activation('relu'),
    Dense(10),
    Activation('softmax')
])

print(model.summary())
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_23 (Conv2D)          (None, 32, 32, 32)        2432
#
#  activation_39 (Activation)  (None, 32, 32, 32)        0
#
#  max_pooling2d_22 (MaxPoolin  (None, 16, 16, 32)       0
#  g2D)
#
#  conv2d_24 (Conv2D)          (None, 12, 12, 64)        51264
#
#  activation_40 (Activation)  (None, 12, 12, 64)        0
#
#  max_pooling2d_23 (MaxPoolin  (None, 6, 6, 64)         0
#  g2D)
#
#  conv2d_25 (Conv2D)          (None, 2, 2, 64)          102464
#
#  activation_41 (Activation)  (None, 2, 2, 64)          0
#
#  max_pooling2d_24 (MaxPoolin  (None, 1, 1, 64)         0
#  g2D)
#
#  flatten_8 (Flatten)         (None, 64)                0
#
#  dense_16 (Dense)            (None, 64)                4160
#
#  activation_42 (Activation)  (None, 64)                0
#
#  dense_17 (Dense)            (None, 10)                650
#
#  activation_43 (Activation)  (None, 10)                0
#
# =================================================================
# Total params: 160,970
# Trainable params: 160,970
# Non-trainable params: 0
# _________________________________________________________________
# None
